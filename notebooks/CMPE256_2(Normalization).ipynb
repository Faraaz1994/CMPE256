# %%
# !pip install keras==2.3.1
#%tensorflow_version 1.x
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from keras.utils import to_categorical
from numpy import asarray
from pathlib import Path
import cv2
import numpy as np

from keras.models import Sequential
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint,EarlyStopping
from numpy import load
from google.colab.patches import cv2_imshow
from google.colab import drive
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
from matplotlib import pyplot
from sklearn.metrics import classification_report
# Out:
# Requirement already satisfied: keras==2.3.1 in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.18.2)

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    print('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
def getListOfImages(source):
     return list(Path(source).glob('**/*.png'))    

def readImages(images,img_width,img_height):
    X=[]
    Y=[]
    for imagePath in images:
        imagePath = str(imagePath)
        imgArr = cv2.imread(imagePath)
        imgArr = cv2.resize(imgArr, (img_width, img_height)) 
        X.append(imgArr)
        Y.append(int(imagePath.split("/")[-1].split("-")[0][3:]) - 1)
    X = asarray(X)
    Y = asarray(Y)
    return (X,Y)

# %%
num_classes = 62
img_width = 64
img_height = 64

source = '/content/drive/My Drive/CMPE256/src'

# %%
#images = getListOfImages(source+'/Data')

# %%
#Takes a lot of time on google colab hence save the data into npz format and directly load it
#%time X,y = readImages(images,img_width,img_height)

# %%
#y = to_categorical(y)

# %%
X = load(source+'/Data/images.npz')
y = load(source+'/Data/labels.npz')
X = X['arr_0']
y = y['arr_0']
num_samples = len(X)
print(X.shape,y.shape)
# Out:
# (74107, 64, 64, 3) (74107, 62)

# %%
#normalization
X = X/255

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,stratify=y, test_size=0.2, random_state=42)

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train,stratify=y_train, test_size=0.2, random_state=42)

# %%
print("Training set : ",X_train.shape,len(X_train)/num_samples * 100 , "% of total samples")
print("Testing set : ",X_test.shape, len(X_test)/num_samples * 100 , "% of total samples")
print("Validation set : ",X_validation.shape, len(X_validation)/num_samples * 100 , "% of total samples")
# Out:
# Training set :  (47428, 64, 64, 3) 63.99935228790803 % of total samples
# Testing set :  (14822, 64, 64, 3) 20.00080964011497 % of total samples
# Validation set :  (11857, 64, 64, 3) 15.999838071977008 % of total samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(img_width, img_height, 3), padding='same', activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=maxnorm(3)))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

lrate=0.01
epochs = 100
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               16777728
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 62)                31806
# =================================================================
# Total params: 16,819,678
# Trainable params: 16,819,678
# Non-trainable params: 0
# _________________________________________________________________

# %%
#checkpoint
filepath= source+"/models/weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=40)
callbacks_list = [checkpoint,es]

# %%
# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), epochs=epochs, batch_size=32,callbacks=callbacks_list)
# Out:
# Train on 47428 samples, validate on 11857 samples
# Epoch 1/100
# 47428/47428 [==============================] - 24s 511us/step - loss: 1.6527 - accuracy: 0.5779 - val_loss: 0.9591 - val_accuracy: 0.7436
# Epoch 2/100
# 47428/47428 [==============================] - 18s 379us/step - loss: 0.9170 - accuracy: 0.7363 - val_loss: 0.7250 - val_accuracy: 0.7908
# Epoch 3/100
# 47428/47428 [==============================] - 18s 378us/step - loss: 0.6903 - accuracy: 0.7867 - val_loss: 0.6157 - val_accuracy: 0.8129
# Epoch 4/100
# 47428/47428 [==============================] - 18s 382us/step - loss: 0.5471 - accuracy: 0.8240 - val_loss: 0.5351 - val_accuracy: 0.8350
# Epoch 5/100
# 47428/47428 [==============================] - 18s 383us/step - loss: 0.4473 - accuracy: 0.8513 - val_loss: 0.5184 - val_accuracy: 0.8367
# Epoch 6/100
# 47428/47428 [==============================] - 18s 381us/step - loss: 0.3734 - accuracy: 0.8725 - val_loss: 0.5058 - val_accuracy: 0.8403
# Epoch 7/100
# 47428/47428 [==============================] - 18s 382us/step - loss: 0.3266 - accuracy: 0.8873 - val_loss: 0.4935 - val_accuracy: 0.8467
# Epoch 8/100
# 47428/47428 [==============================] - 18s 383us/step - loss: 0.2814 - accuracy: 0.9023 - val_loss: 0.4902 - val_accuracy: 0.8485
# Epoch 9/100
# 47428/47428 [==============================] - 18s 381us/step - loss: 0.2502 - accuracy: 0.9114 - val_loss: 0.4791 - val_accuracy: 0.8526
# Epoch 10/100
# 47428/47428 [==============================] - 18s 381us/step - loss: 0.2206 - accuracy: 0.9208 - val_loss: 0.4797 - val_accuracy: 0.8516
# Epoch 11/100
# 47428/47428 [==============================] - 18s 380us/step - loss: 0.2032 - accuracy: 0.9265 - val_loss: 0.4847 - val_accuracy: 0.8559
# Epoch 12/100
# 47428/47428 [==============================] - 18s 380us/step - loss: 0.1872 - accuracy: 0.9315 - val_loss: 0.4770 - val_accuracy: 0.8556
# Epoch 13/100
# 47428/47428 [==============================] - 19s 392us/step - loss: 0.1675 - accuracy: 0.9393 - val_loss: 0.4962 - val_accuracy: 0.8571
# Epoch 14/100
# 47428/47428 [==============================] - 18s 381us/step - loss: 0.1570 - accuracy: 0.9422 - val_loss: 0.5090 - val_accuracy: 0.8587
# Epoch 15/100
# 47428/47428 [==============================] - 18s 382us/step - loss: 0.1436 - accuracy: 0.9480 - val_loss: 0.5021 - val_accuracy: 0.8574
# Epoch 16/100
# 47428/47428 [==============================] - 18s 386us/step - loss: 0.1348 - accuracy: 0.9514 - val_loss: 0.4997 - val_accuracy: 0.8575
# Epoch 17/100
# 47428/47428 [==============================] - 18s 380us/step - loss: 0.1259 - accuracy: 0.9546 - val_loss: 0.5105 - val_accuracy: 0.8582
# Epoch 18/100
# 47428/47428 [==============================] - 18s 380us/step - loss: 0.1204 - accuracy: 0.9559 - val_loss: 0.5141 - val_accuracy: 0.8581
# Epoch 19/100
# 47428/47428 [==============================] - 18s 380us/step - loss: 0.1118 - accuracy: 0.9591 - val_loss: 0.5337 - val_accuracy: 0.8618
# Epoch 20/100
# 47428/47428 [==============================] - 18s 382us/step - loss: 0.1050 - accuracy: 0.9618 - val_loss: 0.5326 - val_accuracy: 0.8605
# Epoch 21/100
# 47428/47428 [==============================] - 18s 381us/step - loss: 0.1018 - accuracy: 0.9625 - val_loss: 0.5390 - val_accuracy: 0.8613
# Epoch 22/100
# 47428/47428 [==============================] - 18s 379us/step - loss: 0.0956 - accuracy: 0.9644 - val_loss: 0.5399 - val_accuracy: 0.8615
# Epoch 23/100
# 47428/47428 [==============================] - 18s 380us/step - loss: 0.0940 - accuracy: 0.9648 - val_loss: 0.5496 - val_accuracy: 0.8629
# Epoch 24/100
# 47428/47428 [==============================] - 18s 387us/step - loss: 0.0867 - accuracy: 0.9672 - val_loss: 0.5525 - val_accuracy: 0.8609
# Epoch 25/100
# 47428/47428 [==============================] - 19s 394us/step - loss: 0.0807 - accuracy: 0.9694 - val_loss: 0.5628 - val_accuracy: 0.8624
# Epoch 26/100
# 47428/47428 [==============================] - 19s 393us/step - loss: 0.0817 - accuracy: 0.9693 - val_loss: 0.5666 - val_accuracy: 0.8630
# Epoch 27/100
# 47428/47428 [==============================] - 19s 409us/step - loss: 0.0784 - accuracy: 0.9701 - val_loss: 0.5563 - val_accuracy: 0.8619
# Epoch 28/100
# 47428/47428 [==============================] - 19s 408us/step - loss: 0.0730 - accuracy: 0.9720 - val_loss: 0.5628 - val_accuracy: 0.8646
# Epoch 29/100
# 47428/47428 [==============================] - 20s 418us/step - loss: 0.0719 - accuracy: 0.9725 - val_loss: 0.5751 - val_accuracy: 0.8618
# Epoch 30/100
# 47428/47428 [==============================] - 20s 415us/step - loss: 0.0706 - accuracy: 0.9732 - val_loss: 0.5785 - val_accuracy: 0.8657
# Epoch 31/100
# 47428/47428 [==============================] - 20s 412us/step - loss: 0.0676 - accuracy: 0.9734 - val_loss: 0.5829 - val_accuracy: 0.8631
# Epoch 32/100
# 47428/47428 [==============================] - 20s 416us/step - loss: 0.0669 - accuracy: 0.9743 - val_loss: 0.5923 - val_accuracy: 0.8630
# Epoch 33/100
# 47428/47428 [==============================] - 19s 410us/step - loss: 0.0639 - accuracy: 0.9758 - val_loss: 0.5887 - val_accuracy: 0.8619
# Epoch 34/100
# 47428/47428 [==============================] - 19s 410us/step - loss: 0.0627 - accuracy: 0.9760 - val_loss: 0.6031 - val_accuracy: 0.8631
# Epoch 35/100
# 47428/47428 [==============================] - 19s 410us/step - loss: 0.0615 - accuracy: 0.9766 - val_loss: 0.6046 - val_accuracy: 0.8654
# Epoch 36/100
# 47428/47428 [==============================] - 19s 409us/step - loss: 0.0571 - accuracy: 0.9776 - val_loss: 0.6047 - val_accuracy: 0.8646
# Epoch 37/100
# 47428/47428 [==============================] - 19s 410us/step - loss: 0.0569 - accuracy: 0.9777 - val_loss: 0.6203 - val_accuracy: 0.8635
# Epoch 38/100
# 47428/47428 [==============================] - 19s 408us/step - loss: 0.0560 - accuracy: 0.9786 - val_loss: 0.6230 - val_accuracy: 0.8639
# Epoch 39/100
# 47428/47428 [==============================] - 19s 408us/step - loss: 0.0545 - accuracy: 0.9787 - val_loss: 0.6207 - val_accuracy: 0.8645
# Epoch 40/100
# 47428/47428 [==============================] - 19s 409us/step - loss: 0.0526 - accuracy: 0.9789 - val_loss: 0.6224 - val_accuracy: 0.8648
# Epoch 41/100
# 47428/47428 [==============================] - 19s 408us/step - loss: 0.0513 - accuracy: 0.9801 - val_loss: 0.6276 - val_accuracy: 0.8651
# Epoch 42/100
# 47428/47428 [==============================] - 19s 409us/step - loss: 0.0496 - accuracy: 0.9805 - val_loss: 0.6313 - val_accuracy: 0.8647
# Epoch 43/100
# 47428/47428 [==============================] - 19s 407us/step - loss: 0.0509 - accuracy: 0.9797 - val_loss: 0.6333 - val_accuracy: 0.8652
# Epoch 44/100
# 47428/47428 [==============================] - 19s 408us/step - loss: 0.0479 - accuracy: 0.9809 - val_loss: 0.6503 - val_accuracy: 0.8663
# Epoch 45/100
# 47428/47428 [==============================] - 20s 424us/step - loss: 0.0486 - accuracy: 0.9813 - val_loss: 0.6419 - val_accuracy: 0.8655
# Epoch 46/100
# 47428/47428 [==============================] - 20s 412us/step - loss: 0.0472 - accuracy: 0.9811 - val_loss: 0.6461 - val_accuracy: 0.8654
# Epoch 47/100
# 47428/47428 [==============================] - 19s 407us/step - loss: 0.0455 - accuracy: 0.9818 - val_loss: 0.6551 - val_accuracy: 0.8660
# Epoch 48/100
# 47428/47428 [==============================] - 20s 413us/step - loss: 0.0452 - accuracy: 0.9812 - val_loss: 0.6503 - val_accuracy: 0.8653
# Epoch 49/100
# 47428/47428 [==============================] - 19s 407us/step - loss: 0.0442 - accuracy: 0.9821 - val_loss: 0.6601 - val_accuracy: 0.8671
# Epoch 50/100
# 47428/47428 [==============================] - 19s 408us/step - loss: 0.0426 - accuracy: 0.9829 - val_loss: 0.6586 - val_accuracy: 0.8652
# Epoch 51/100
# 47428/47428 [==============================] - 19s 407us/step - loss: 0.0440 - accuracy: 0.9824 - val_loss: 0.6654 - val_accuracy: 0.8656
# Epoch 52/100
# 47428/47428 [==============================] - 19s 408us/step - loss: 0.0425 - accuracy: 0.9825 - val_loss: 0.6669 - val_accuracy: 0.8651

# %%
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 87.61%

# %%
from IPython.display import SVG
from keras.utils import model_to_dot
#model
SVG(model_to_dot(model,show_shapes=True,expand_nested=True,dpi=50).create(prog='dot', format='svg'))

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
def createConfusionMatrix(trueLabel,PredictedLabel):
    cm=confusion_matrix(trueLabel,PredictedLabel,normalize="true")
    return np.around(cm, decimals=2)

# %%
def plotConfusionMatrix(matrix):
  df_cm = pd.DataFrame(matrix,range(matrix.shape[0]),range(matrix.shape[1]))
  plt.figure(figsize = (50,50))
  sn.set(font_scale=1.5)
  sn.heatmap(df_cm, annot=True, annot_kws={"size": 15})

# %%
#Get the predicted classes for all the samples in testing set
y_pred = model.predict_classes(X_test)

# %%
#Create and plot the confusion matrix
cm = createConfusionMatrix(y_test.argmax(axis=1),y_pred)
plotConfusionMatrix(cm)

# %%
print(classification_report(y_test.argmax(axis=1),y_pred,zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69       235
#            1       0.87      0.87      0.87       230
#            2       0.98      0.97      0.97       228
#            3       0.96      0.96      0.96       224
#            4       0.94      0.96      0.95       224
#            5       0.97      0.98      0.97       227
#            6       0.94      0.96      0.95       227
#            7       0.96      0.96      0.96       224
#            8       0.97      0.94      0.95       220
#            9       0.94      0.93      0.94       221
#           10       0.93      0.95      0.94       326
#           11       0.91      0.92      0.91       237
#           12       0.78      0.83      0.81       257
#           13       0.94      0.96      0.95       252
#           14       0.90      0.92      0.91       303
#           15       0.93      0.93      0.93       230
#           16       0.91      0.90      0.90       243
#           17       0.92      0.94      0.93       253
#           18       0.81      0.82      0.81       275
#           19       0.89      0.92      0.91       230
#           20       0.93      0.97      0.95       233
#           21       0.91      0.93      0.92       257
#           22       0.91      0.94      0.93       244
#           23       0.93      0.95      0.94       287
#           24       0.63      0.67      0.65       291
#           25       0.91      0.90      0.91       246
#           26       0.90      0.90      0.90       221
#           27       0.92      0.93      0.93       292
#           28       0.74      0.80      0.77       283
#           29       0.87      0.92      0.90       277
#           30       0.86      0.90      0.88       233
#           31       0.82      0.71      0.76       231
#           32       0.79      0.78      0.78       228
#           33       0.83      0.76      0.79       230
#           34       0.91      0.92      0.91       228
#           35       0.77      0.85      0.81       225
#           36       0.87      0.87      0.87       246
#           37       0.91      0.90      0.91       222
#           38       0.84      0.78      0.81       227
#           39       0.94      0.94      0.94       223
#           40       0.92      0.92      0.92       260
#           41       0.94      0.90      0.92       221
#           42       0.94      0.87      0.90       221
#           43       0.92      0.92      0.92       225
#           44       0.91      0.90      0.91       240
#           45       0.96      0.89      0.92       221
#           46       0.97      0.89      0.93       221
#           47       0.76      0.83      0.79       226
#           48       0.91      0.92      0.92       223
#           49       0.90      0.92      0.91       241
#           50       0.65      0.63      0.64       244
#           51       0.92      0.90      0.91       221
#           52       0.88      0.91      0.89       225
#           53       0.90      0.89      0.90       239
#           54       0.75      0.68      0.71       239
#           55       0.93      0.92      0.92       236
#           56       0.88      0.86      0.87       222
#           57       0.72      0.80      0.76       221
#           58       0.79      0.77      0.78       221
#           59       0.78      0.78      0.78       221
#           60       0.92      0.88      0.90       223
#           61       0.85      0.68      0.76       221
#
#     accuracy                           0.88     14822
#    macro avg       0.88      0.88      0.88     14822
# weighted avg       0.88      0.88      0.88     14822
