# %%
# !pip install keras==2.3.1
#%tensorflow_version 1.x
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from keras.utils import to_categorical
from numpy import asarray
from pathlib import Path
import cv2
import numpy as np

from keras.models import Sequential
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint,EarlyStopping
from numpy import load
#from google.colab.patches import cv2_imshow
#from google.colab import drive
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
from matplotlib import pyplot
from sklearn.metrics import classification_report
from sklearn import preprocessing
# Out:
# Requirement already satisfied: keras==2.3.1 in /opt/anaconda3/lib/python3.7/site-packages (2.3.1)
# Requirement already satisfied: scipy>=0.14 in /opt/anaconda3/lib/python3.7/site-packages (from keras==2.3.1) (1.4.1)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.7/site-packages (from keras==2.3.1) (5.1.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/anaconda3/lib/python3.7/site-packages (from keras==2.3.1) (1.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/anaconda3/lib/python3.7/site-packages (from keras==2.3.1) (1.17.2)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.7/site-packages (from keras==2.3.1) (1.12.0)
# Requirement already satisfied: h5py in /opt/anaconda3/lib/python3.7/site-packages (from keras==2.3.1) (2.9.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/anaconda3/lib/python3.7/site-packages (from keras==2.3.1) (1.0.8)

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    print('GPU device not found')
print('Found GPU at: {}'.format(device_name))

# %%
drive.mount('/content/drive')

# %%
def getListOfImages(source):
     return list(Path(source).glob('**/*.png'))    

def readImages(images,img_width,img_height):
    X=[]
    Y=[]
    for imagePath in images:
        imagePath = str(imagePath)
        imgArr = cv2.imread(imagePath)
        imgArr = cv2.resize(imgArr, (img_width, img_height)) 
        X.append(imgArr)
        Y.append(int(imagePath.split("/")[-1].split("-")[0][3:]) - 1)
    X = asarray(X)
    Y = asarray(Y)
    return (X,Y)

# %%
num_classes = 62
img_width = 64
img_height = 64

source = '/content/drive/My Drive/CMPE256/src'

# %%
#images = getListOfImages(source)

# %%
#Takes a lot of time on google colab hence save the data into npz format and directly load it
#%time X,y = readImages(images,img_width,img_height)

# %%
#y = to_categorical(y)

# %%
X = load(source+'/Data/images.npz')
y = load(source+'/Data/labels.npz')
X = X['arr_0']
y = y['arr_0']
num_samples = len(X)
print(X.shape,y.shape)
# Out:
# (74107, 64, 64, 3) (74107, 62)

# %%
#[123,45323,234,9876,55555]:
img = X[55555]
dst = cv2.fastNlMeansDenoisingColored(img,None,10,10,7,21)
md = cv2.medianBlur(img,5)
plt.subplot(131),plt.title("Normal image"),plt.imshow(img),
plt.subplot(132),plt.title("MeansDenoising"),plt.imshow(dst)
plt.subplot(133),plt.title("MedianBlur"),plt.imshow(md)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1533dde10>,
#  Text(0.5, 1.0, 'MedianBlur'),
#  <matplotlib.image.AxesImage at 0x1533f8c50>)

# %%
for i in range(num_samples):
  X[i] = cv2.medianBlur(X[i],5)

# %%
#Normalization https://machinelearningmastery.com/how-to-manually-scale-image-pixel-data-for-deep-learning/
#1)  X = X/255
X = X/255

#2) Standardizatin
#X = X.astype(float)
#X =  (X - X.mean())/X.std()


#3)Normalization + Standardization
#X = X.astype(float)
#X = X/255
#X =  (X - X.mean())/X.std()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,stratify=y, test_size=0.2, random_state=42)

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train,stratify=y_train, test_size=0.2, random_state=42)

# %%
print("Training set : ",X_train.shape,len(X_train)/num_samples * 100 , "% of total samples")
print("Testing set : ",X_test.shape, len(X_test)/num_samples * 100 , "% of total samples")
print("Validation set : ",X_validation.shape, len(X_validation)/num_samples * 100 , "% of total samples")
# Out:
# Training set :  (47428, 64, 64, 3) 63.99935228790803 % of total samples
# Testing set :  (14822, 64, 64, 3) 20.00080964011497 % of total samples
# Validation set :  (11857, 64, 64, 3) 15.999838071977008 % of total samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(img_width, img_height, 3), padding='same', activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=maxnorm(3)))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

lrate=0.01
epochs = 100
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               16777728
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 62)                31806
# =================================================================
# Total params: 16,819,678
# Trainable params: 16,819,678
# Non-trainable params: 0
# _________________________________________________________________

# %%
#checkpoint
filepath= source+"/models/weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=40)
callbacks_list = [checkpoint,es]

# %%
# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), epochs=epochs, batch_size=32,callbacks=callbacks_list)
# Out:
# Train on 47428 samples, validate on 11857 samples
# Epoch 1/100
# 47428/47428 [==============================] - 25s 528us/step - loss: 1.7905 - accuracy: 0.5479 - val_loss: 1.0468 - val_accuracy: 0.7181
# Epoch 2/100
# 47428/47428 [==============================] - 19s 395us/step - loss: 0.9680 - accuracy: 0.7267 - val_loss: 0.7523 - val_accuracy: 0.7823
# Epoch 3/100
# 47428/47428 [==============================] - 18s 390us/step - loss: 0.7301 - accuracy: 0.7808 - val_loss: 0.6792 - val_accuracy: 0.7913
# Epoch 4/100
# 47428/47428 [==============================] - 19s 391us/step - loss: 0.5959 - accuracy: 0.8123 - val_loss: 0.6075 - val_accuracy: 0.8160
# Epoch 5/100
# 47428/47428 [==============================] - 19s 393us/step - loss: 0.4898 - accuracy: 0.8394 - val_loss: 0.5911 - val_accuracy: 0.8228
# Epoch 6/100
# 47428/47428 [==============================] - 19s 404us/step - loss: 0.4140 - accuracy: 0.8624 - val_loss: 0.5623 - val_accuracy: 0.8251
# Epoch 7/100
# 47428/47428 [==============================] - 19s 401us/step - loss: 0.3593 - accuracy: 0.8787 - val_loss: 0.5604 - val_accuracy: 0.8285
# Epoch 8/100
# 47428/47428 [==============================] - 19s 400us/step - loss: 0.3199 - accuracy: 0.8904 - val_loss: 0.5702 - val_accuracy: 0.8330
# Epoch 9/100
# 47428/47428 [==============================] - 19s 404us/step - loss: 0.2800 - accuracy: 0.9029 - val_loss: 0.5523 - val_accuracy: 0.8366
# Epoch 10/100
# 47428/47428 [==============================] - 20s 414us/step - loss: 0.2499 - accuracy: 0.9133 - val_loss: 0.5600 - val_accuracy: 0.8353
# Epoch 11/100
# 47428/47428 [==============================] - 19s 402us/step - loss: 0.2280 - accuracy: 0.9211 - val_loss: 0.5671 - val_accuracy: 0.8376
# Epoch 12/100
# 47428/47428 [==============================] - 19s 403us/step - loss: 0.2063 - accuracy: 0.9278 - val_loss: 0.5672 - val_accuracy: 0.8392
# Epoch 13/100
# 47428/47428 [==============================] - 19s 405us/step - loss: 0.1889 - accuracy: 0.9334 - val_loss: 0.5759 - val_accuracy: 0.8387
# Epoch 14/100
# 47428/47428 [==============================] - 19s 404us/step - loss: 0.1733 - accuracy: 0.9396 - val_loss: 0.6073 - val_accuracy: 0.8427
# Epoch 15/100
# 47428/47428 [==============================] - 19s 410us/step - loss: 0.1665 - accuracy: 0.9420 - val_loss: 0.5930 - val_accuracy: 0.8435
# Epoch 16/100
# 47428/47428 [==============================] - 19s 409us/step - loss: 0.1554 - accuracy: 0.9453 - val_loss: 0.5974 - val_accuracy: 0.8422
# Epoch 17/100
# 47428/47428 [==============================] - 19s 407us/step - loss: 0.1435 - accuracy: 0.9487 - val_loss: 0.6255 - val_accuracy: 0.8424
# Epoch 18/100
# 47428/47428 [==============================] - 19s 407us/step - loss: 0.1372 - accuracy: 0.9526 - val_loss: 0.6103 - val_accuracy: 0.8427
# Epoch 19/100
# 47428/47428 [==============================] - 19s 407us/step - loss: 0.1294 - accuracy: 0.9552 - val_loss: 0.6308 - val_accuracy: 0.8426
# Epoch 20/100
# 47428/47428 [==============================] - 19s 408us/step - loss: 0.1240 - accuracy: 0.9567 - val_loss: 0.6175 - val_accuracy: 0.8422
# Epoch 21/100
# 47428/47428 [==============================] - 19s 409us/step - loss: 0.1193 - accuracy: 0.9576 - val_loss: 0.6198 - val_accuracy: 0.8431
# Epoch 22/100
# 47428/47428 [==============================] - 20s 413us/step - loss: 0.1142 - accuracy: 0.9606 - val_loss: 0.6481 - val_accuracy: 0.8436
# Epoch 23/100
# 47428/47428 [==============================] - 20s 413us/step - loss: 0.1092 - accuracy: 0.9618 - val_loss: 0.6347 - val_accuracy: 0.8476
# Epoch 24/100
# 47428/47428 [==============================] - 19s 411us/step - loss: 0.1059 - accuracy: 0.9635 - val_loss: 0.6488 - val_accuracy: 0.8465
# Epoch 25/100
# 47428/47428 [==============================] - 19s 409us/step - loss: 0.1009 - accuracy: 0.9638 - val_loss: 0.6396 - val_accuracy: 0.8479
# Epoch 26/100
# 47428/47428 [==============================] - 20s 422us/step - loss: 0.0931 - accuracy: 0.9673 - val_loss: 0.6738 - val_accuracy: 0.8480
# Epoch 27/100
# 47428/47428 [==============================] - 20s 419us/step - loss: 0.0927 - accuracy: 0.9680 - val_loss: 0.6760 - val_accuracy: 0.8454
# Epoch 28/100
# 47428/47428 [==============================] - 20s 412us/step - loss: 0.0943 - accuracy: 0.9670 - val_loss: 0.6708 - val_accuracy: 0.8468
# Epoch 29/100
# 47428/47428 [==============================] - 20s 412us/step - loss: 0.0879 - accuracy: 0.9690 - val_loss: 0.6670 - val_accuracy: 0.8500
# Epoch 30/100
# 47428/47428 [==============================] - 20s 414us/step - loss: 0.0822 - accuracy: 0.9707 - val_loss: 0.6839 - val_accuracy: 0.8472
# Epoch 31/100
# 47428/47428 [==============================] - 20s 412us/step - loss: 0.0829 - accuracy: 0.9704 - val_loss: 0.6724 - val_accuracy: 0.8468
# Epoch 32/100
# 47428/47428 [==============================] - 19s 411us/step - loss: 0.0793 - accuracy: 0.9710 - val_loss: 0.6926 - val_accuracy: 0.8480
# Epoch 33/100
# 47428/47428 [==============================] - 20s 412us/step - loss: 0.0780 - accuracy: 0.9727 - val_loss: 0.6946 - val_accuracy: 0.8492
# Epoch 34/100
# 47428/47428 [==============================] - 20s 413us/step - loss: 0.0772 - accuracy: 0.9729 - val_loss: 0.6985 - val_accuracy: 0.8468
# Epoch 35/100
# 47428/47428 [==============================] - 20s 416us/step - loss: 0.0750 - accuracy: 0.9729 - val_loss: 0.7080 - val_accuracy: 0.8496
# Epoch 36/100
# 47428/47428 [==============================] - 20s 413us/step - loss: 0.0747 - accuracy: 0.9739 - val_loss: 0.7023 - val_accuracy: 0.8498
# Epoch 37/100
# 47428/47428 [==============================] - 20s 419us/step - loss: 0.0722 - accuracy: 0.9742 - val_loss: 0.7298 - val_accuracy: 0.8501
# Epoch 38/100
# 47428/47428 [==============================] - 20s 416us/step - loss: 0.0694 - accuracy: 0.9753 - val_loss: 0.7279 - val_accuracy: 0.8496
# Epoch 39/100
# 47428/47428 [==============================] - 20s 413us/step - loss: 0.0674 - accuracy: 0.9758 - val_loss: 0.7250 - val_accuracy: 0.8514
# Epoch 40/100
# 47428/47428 [==============================] - 20s 414us/step - loss: 0.0654 - accuracy: 0.9754 - val_loss: 0.7430 - val_accuracy: 0.8522
# Epoch 41/100
# 47428/47428 [==============================] - 20s 415us/step - loss: 0.0655 - accuracy: 0.9762 - val_loss: 0.7357 - val_accuracy: 0.8500
# Epoch 42/100
# 47428/47428 [==============================] - 20s 424us/step - loss: 0.0632 - accuracy: 0.9772 - val_loss: 0.7434 - val_accuracy: 0.8490
# Epoch 43/100
# 47428/47428 [==============================] - 20s 412us/step - loss: 0.0637 - accuracy: 0.9771 - val_loss: 0.7494 - val_accuracy: 0.8497
# Epoch 44/100
# 47428/47428 [==============================] - 20s 417us/step - loss: 0.0639 - accuracy: 0.9768 - val_loss: 0.7356 - val_accuracy: 0.8496
# Epoch 45/100
# 47428/47428 [==============================] - 20s 412us/step - loss: 0.0590 - accuracy: 0.9783 - val_loss: 0.7509 - val_accuracy: 0.8487
# Epoch 46/100
# 47428/47428 [==============================] - 20s 415us/step - loss: 0.0617 - accuracy: 0.9780 - val_loss: 0.7456 - val_accuracy: 0.8496
# Epoch 47/100
# 47428/47428 [==============================] - 20s 415us/step - loss: 0.0594 - accuracy: 0.9782 - val_loss: 0.7558 - val_accuracy: 0.8491
# Epoch 48/100
# 47428/47428 [==============================] - 20s 413us/step - loss: 0.0586 - accuracy: 0.9789 - val_loss: 0.7525 - val_accuracy: 0.8494
# Epoch 49/100
# 47428/47428 [==============================] - 20s 413us/step - loss: 0.0582 - accuracy: 0.9788 - val_loss: 0.7652 - val_accuracy: 0.8502

# %%
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 85.83%

# %%
from IPython.display import SVG
from keras.utils import model_to_dot
#model
SVG(model_to_dot(model,show_shapes=True,expand_nested=True,dpi=50).create(prog='dot', format='svg'))

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
def createConfusionMatrix(trueLabel,PredictedLabel):
    cm=confusion_matrix(trueLabel,PredictedLabel,normalize="true")
    return np.around(cm, decimals=2)

# %%
def plotConfusionMatrix(matrix):
  df_cm = pd.DataFrame(matrix,range(matrix.shape[0]),range(matrix.shape[1]))
  plt.figure(figsize = (50,50))
  sn.set(font_scale=1.5)
  sn.heatmap(df_cm, annot=True, annot_kws={"size": 15})

# %%
#Get the predicted classes for all the samples in testing set
y_pred = model.predict_classes(X_test)

# %%
#Create and plot the confusion matrix
cm = createConfusionMatrix(y_test.argmax(axis=1),y_pred)
plotConfusionMatrix(cm)

# %%
print(classification_report(y_test.argmax(axis=1),y_pred,zero_division=0)) #
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71       235
#            1       0.86      0.84      0.85       230
#            2       0.96      0.96      0.96       228
#            3       0.97      0.92      0.95       224
#            4       0.95      0.94      0.95       224
#            5       0.94      0.96      0.95       227
#            6       0.91      0.96      0.93       227
#            7       0.96      0.94      0.95       224
#            8       0.97      0.91      0.94       220
#            9       0.93      0.90      0.92       221
#           10       0.91      0.94      0.92       326
#           11       0.93      0.90      0.92       237
#           12       0.77      0.79      0.78       257
#           13       0.91      0.91      0.91       252
#           14       0.92      0.93      0.92       303
#           15       0.91      0.92      0.91       230
#           16       0.90      0.88      0.89       243
#           17       0.91      0.91      0.91       253
#           18       0.71      0.81      0.76       275
#           19       0.88      0.92      0.90       230
#           20       0.92      0.93      0.93       233
#           21       0.93      0.91      0.92       257
#           22       0.91      0.93      0.92       244
#           23       0.93      0.94      0.94       287
#           24       0.59      0.65      0.62       291
#           25       0.92      0.87      0.90       246
#           26       0.90      0.89      0.89       221
#           27       0.92      0.92      0.92       292
#           28       0.75      0.77      0.76       283
#           29       0.89      0.91      0.90       277
#           30       0.81      0.88      0.84       233
#           31       0.77      0.70      0.73       231
#           32       0.79      0.75      0.77       228
#           33       0.77      0.76      0.77       230
#           34       0.89      0.90      0.90       228
#           35       0.76      0.80      0.77       225
#           36       0.89      0.83      0.86       246
#           37       0.89      0.88      0.89       222
#           38       0.78      0.73      0.75       227
#           39       0.92      0.91      0.92       223
#           40       0.88      0.90      0.89       260
#           41       0.92      0.88      0.90       221
#           42       0.83      0.85      0.84       221
#           43       0.91      0.90      0.91       225
#           44       0.88      0.89      0.88       240
#           45       0.95      0.86      0.90       221
#           46       0.93      0.87      0.90       221
#           47       0.70      0.85      0.77       226
#           48       0.91      0.91      0.91       223
#           49       0.90      0.89      0.90       241
#           50       0.64      0.64      0.64       244
#           51       0.90      0.86      0.88       221
#           52       0.88      0.90      0.89       225
#           53       0.86      0.88      0.87       239
#           54       0.72      0.70      0.71       239
#           55       0.91      0.91      0.91       236
#           56       0.88      0.86      0.87       222
#           57       0.75      0.73      0.74       221
#           58       0.79      0.75      0.77       221
#           59       0.76      0.78      0.77       221
#           60       0.88      0.86      0.87       223
#           61       0.77      0.69      0.73       221
#
#     accuracy                           0.86     14822
#    macro avg       0.86      0.86      0.86     14822
# weighted avg       0.86      0.86      0.86     14822
