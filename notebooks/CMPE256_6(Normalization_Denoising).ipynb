# %%
# !pip install keras==2.3.1
#%tensorflow_version 1.x
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from keras.utils import to_categorical
from numpy import asarray
from pathlib import Path
import cv2
import numpy as np

from keras.models import Sequential
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint,EarlyStopping
from numpy import load
from google.colab.patches import cv2_imshow
from google.colab import drive
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
from matplotlib import pyplot
from sklearn.metrics import classification_report
from sklearn import preprocessing
# Out:
# Requirement already satisfied: keras==2.3.1 in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.12.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.18.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.1.0)
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    print('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
def getListOfImages(source):
     return list(Path(source).glob('**/*.png'))    

def readImages(images,img_width,img_height):
    X=[]
    Y=[]
    for imagePath in images:
        imagePath = str(imagePath)
        imgArr = cv2.imread(imagePath)
        imgArr = cv2.resize(imgArr, (img_width, img_height)) 
        X.append(imgArr)
        Y.append(int(imagePath.split("/")[-1].split("-")[0][3:]) - 1)
    X = asarray(X)
    Y = asarray(Y)
    return (X,Y)

# %%
num_classes = 62
img_width = 64
img_height = 64

source = '/content/drive/My Drive/CMPE256/src'

# %%
#images = getListOfImages(source+'/Data')

# %%
#Takes a lot of time on google colab hence save the data into npz format and directly load it
#%time X,y = readImages(images,img_width,img_height)

# %%
#y = to_categorical(y)

# %%
X = load(source+'/Data/images.npz')
y = load(source+'/Data/labels.npz')
X = X['arr_0']
y = y['arr_0']
num_samples = len(X)
print(X.shape,y.shape)
# Out:
# (74107, 64, 64, 3) (74107, 62)

# %%
img = X[70000]
dst = cv2.fastNlMeansDenoisingColored(img,None,10,10,7,21)
md = cv2.medianBlur(img,5)
plt.subplot(131),plt.imshow(img)
plt.subplot(132),plt.imshow(dst)
plt.subplot(133),plt.imshow(md)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fbb8a1686d8>,
#  <matplotlib.image.AxesImage at 0x7fbb8a0cee80>)

# %%
for i in range(num_samples):
  X[i] = cv2.fastNlMeansDenoisingColored(X[i],None,10,10,7,21)

# %%
#Normalization https://machinelearningmastery.com/how-to-manually-scale-image-pixel-data-for-deep-learning/
#1)  X = X/255
X = X/255

#2) Standardizatin
#X = X.astype(float)
#X =  (X - X.mean())/X.std()


#3)Normalization + Standardization
#X = X.astype(float)
#X = X/255
#X =  (X - X.mean())/X.std()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,stratify=y, test_size=0.2, random_state=42)

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train,stratify=y_train, test_size=0.2, random_state=42)

# %%
print("Training set : ",X_train.shape,len(X_train)/num_samples * 100 , "% of total samples")
print("Testing set : ",X_test.shape, len(X_test)/num_samples * 100 , "% of total samples")
print("Validation set : ",X_validation.shape, len(X_validation)/num_samples * 100 , "% of total samples")
# Out:
# Training set :  (47428, 64, 64, 3) 63.99935228790803 % of total samples
# Testing set :  (14822, 64, 64, 3) 20.00080964011497 % of total samples
# Validation set :  (11857, 64, 64, 3) 15.999838071977008 % of total samples

# %%
del X

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(img_width, img_height, 3), padding='same', activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=maxnorm(3)))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

lrate=0.01
epochs = 100
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               16777728
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 62)                31806
# =================================================================
# Total params: 16,819,678
# Trainable params: 16,819,678
# Non-trainable params: 0
# _________________________________________________________________

# %%
#checkpoint
filepath= source+"/models/weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=40)
callbacks_list = [checkpoint,es]

# %%
# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), epochs=epochs, batch_size=32,callbacks=callbacks_list)
# Out:
# Train on 47428 samples, validate on 11857 samples
# Epoch 1/100
# 47428/47428 [==============================] - 23s 488us/step - loss: 1.7220 - accuracy: 0.5624 - val_loss: 0.9658 - val_accuracy: 0.7337
# Epoch 2/100
# 47428/47428 [==============================] - 17s 367us/step - loss: 0.9733 - accuracy: 0.7250 - val_loss: 0.7644 - val_accuracy: 0.7775
# Epoch 3/100
# 47428/47428 [==============================] - 17s 369us/step - loss: 0.7594 - accuracy: 0.7729 - val_loss: 0.6860 - val_accuracy: 0.7964
# Epoch 4/100
# 47428/47428 [==============================] - 17s 368us/step - loss: 0.6168 - accuracy: 0.8070 - val_loss: 0.6125 - val_accuracy: 0.8131
# Epoch 5/100
# 47428/47428 [==============================] - 18s 378us/step - loss: 0.5116 - accuracy: 0.8359 - val_loss: 0.5587 - val_accuracy: 0.8262
# Epoch 6/100
# 47428/47428 [==============================] - 18s 381us/step - loss: 0.4290 - accuracy: 0.8580 - val_loss: 0.5202 - val_accuracy: 0.8382
# Epoch 7/100
# 47428/47428 [==============================] - 18s 371us/step - loss: 0.3741 - accuracy: 0.8743 - val_loss: 0.5384 - val_accuracy: 0.8344
# Epoch 8/100
# 47428/47428 [==============================] - 18s 383us/step - loss: 0.3313 - accuracy: 0.8871 - val_loss: 0.5167 - val_accuracy: 0.8448
# Epoch 9/100
# 47428/47428 [==============================] - 18s 379us/step - loss: 0.2923 - accuracy: 0.8992 - val_loss: 0.5397 - val_accuracy: 0.8441
# Epoch 10/100
# 47428/47428 [==============================] - 18s 372us/step - loss: 0.2652 - accuracy: 0.9079 - val_loss: 0.5062 - val_accuracy: 0.8495
# Epoch 11/100
# 47428/47428 [==============================] - 18s 377us/step - loss: 0.2388 - accuracy: 0.9163 - val_loss: 0.5195 - val_accuracy: 0.8506
# Epoch 12/100
# 47428/47428 [==============================] - 18s 379us/step - loss: 0.2154 - accuracy: 0.9249 - val_loss: 0.5282 - val_accuracy: 0.8502
# Epoch 13/100
# 47428/47428 [==============================] - 18s 378us/step - loss: 0.1966 - accuracy: 0.9302 - val_loss: 0.5182 - val_accuracy: 0.8492
# Epoch 14/100
# 47428/47428 [==============================] - 18s 379us/step - loss: 0.1836 - accuracy: 0.9348 - val_loss: 0.5225 - val_accuracy: 0.8543
# Epoch 15/100
# 47428/47428 [==============================] - 18s 379us/step - loss: 0.1719 - accuracy: 0.9388 - val_loss: 0.5322 - val_accuracy: 0.8515
# Epoch 16/100
# 47428/47428 [==============================] - 18s 382us/step - loss: 0.1634 - accuracy: 0.9414 - val_loss: 0.5365 - val_accuracy: 0.8543
# Epoch 17/100
# 47428/47428 [==============================] - 18s 382us/step - loss: 0.1488 - accuracy: 0.9471 - val_loss: 0.5415 - val_accuracy: 0.8526
# Epoch 18/100
# 47428/47428 [==============================] - 18s 378us/step - loss: 0.1435 - accuracy: 0.9491 - val_loss: 0.5488 - val_accuracy: 0.8583
# Epoch 19/100
# 47428/47428 [==============================] - 18s 380us/step - loss: 0.1334 - accuracy: 0.9527 - val_loss: 0.5601 - val_accuracy: 0.8532
# Epoch 20/100
# 47428/47428 [==============================] - 18s 383us/step - loss: 0.1206 - accuracy: 0.9547 - val_loss: 0.5590 - val_accuracy: 0.8559
# Epoch 21/100
# 47428/47428 [==============================] - 18s 380us/step - loss: 0.1223 - accuracy: 0.9548 - val_loss: 0.5591 - val_accuracy: 0.8566
# Epoch 22/100
# 47428/47428 [==============================] - 18s 378us/step - loss: 0.1116 - accuracy: 0.9602 - val_loss: 0.5770 - val_accuracy: 0.8575
# Epoch 23/100
# 47428/47428 [==============================] - 18s 377us/step - loss: 0.1089 - accuracy: 0.9609 - val_loss: 0.5643 - val_accuracy: 0.8574
# Epoch 24/100
# 47428/47428 [==============================] - 18s 380us/step - loss: 0.1048 - accuracy: 0.9617 - val_loss: 0.5713 - val_accuracy: 0.8574
# Epoch 25/100
# 47428/47428 [==============================] - 18s 377us/step - loss: 0.0975 - accuracy: 0.9637 - val_loss: 0.6043 - val_accuracy: 0.8588
# Epoch 26/100
# 47428/47428 [==============================] - 18s 384us/step - loss: 0.0954 - accuracy: 0.9648 - val_loss: 0.5788 - val_accuracy: 0.8601
# Epoch 27/100
# 47428/47428 [==============================] - 18s 384us/step - loss: 0.0896 - accuracy: 0.9666 - val_loss: 0.5942 - val_accuracy: 0.8595
# Epoch 28/100
# 47428/47428 [==============================] - 18s 386us/step - loss: 0.0891 - accuracy: 0.9677 - val_loss: 0.5988 - val_accuracy: 0.8595
# Epoch 29/100
# 47428/47428 [==============================] - 18s 387us/step - loss: 0.0832 - accuracy: 0.9690 - val_loss: 0.5887 - val_accuracy: 0.8604
# Epoch 30/100
# 47428/47428 [==============================] - 18s 386us/step - loss: 0.0823 - accuracy: 0.9686 - val_loss: 0.6108 - val_accuracy: 0.8582
# Epoch 31/100
# 47428/47428 [==============================] - 18s 383us/step - loss: 0.0793 - accuracy: 0.9698 - val_loss: 0.6228 - val_accuracy: 0.8594
# Epoch 32/100
# 47428/47428 [==============================] - 18s 384us/step - loss: 0.0751 - accuracy: 0.9717 - val_loss: 0.6242 - val_accuracy: 0.8619
# Epoch 33/100
# 47428/47428 [==============================] - 18s 390us/step - loss: 0.0736 - accuracy: 0.9726 - val_loss: 0.6214 - val_accuracy: 0.8608
# Epoch 34/100
# 47428/47428 [==============================] - 18s 388us/step - loss: 0.0734 - accuracy: 0.9727 - val_loss: 0.6240 - val_accuracy: 0.8603
# Epoch 35/100
# 47428/47428 [==============================] - 18s 383us/step - loss: 0.0690 - accuracy: 0.9741 - val_loss: 0.6213 - val_accuracy: 0.8626
# Epoch 36/100
# 47428/47428 [==============================] - 18s 385us/step - loss: 0.0662 - accuracy: 0.9748 - val_loss: 0.6526 - val_accuracy: 0.8598
# Epoch 37/100
# 47428/47428 [==============================] - 18s 387us/step - loss: 0.0658 - accuracy: 0.9752 - val_loss: 0.6410 - val_accuracy: 0.8626
# Epoch 38/100
# 47428/47428 [==============================] - 18s 383us/step - loss: 0.0628 - accuracy: 0.9756 - val_loss: 0.6562 - val_accuracy: 0.8609
# Epoch 39/100
# 47428/47428 [==============================] - 18s 387us/step - loss: 0.0600 - accuracy: 0.9765 - val_loss: 0.6698 - val_accuracy: 0.8607
# Epoch 40/100
# 47428/47428 [==============================] - 18s 383us/step - loss: 0.0610 - accuracy: 0.9765 - val_loss: 0.6419 - val_accuracy: 0.8616
# Epoch 41/100
# 47428/47428 [==============================] - 18s 386us/step - loss: 0.0591 - accuracy: 0.9776 - val_loss: 0.6695 - val_accuracy: 0.8609
# Epoch 42/100
# 47428/47428 [==============================] - 18s 385us/step - loss: 0.0587 - accuracy: 0.9767 - val_loss: 0.6703 - val_accuracy: 0.8612
# Epoch 43/100
# 47428/47428 [==============================] - 18s 385us/step - loss: 0.0564 - accuracy: 0.9786 - val_loss: 0.6726 - val_accuracy: 0.8630
# Epoch 44/100
# 47428/47428 [==============================] - 18s 386us/step - loss: 0.0551 - accuracy: 0.9789 - val_loss: 0.6794 - val_accuracy: 0.8593
# Epoch 45/100
# 47428/47428 [==============================] - 18s 385us/step - loss: 0.0536 - accuracy: 0.9795 - val_loss: 0.6863 - val_accuracy: 0.8619
# Epoch 46/100
# 47428/47428 [==============================] - 18s 389us/step - loss: 0.0517 - accuracy: 0.9802 - val_loss: 0.6958 - val_accuracy: 0.8623
# Epoch 47/100
# 47428/47428 [==============================] - 18s 385us/step - loss: 0.0521 - accuracy: 0.9794 - val_loss: 0.6923 - val_accuracy: 0.8623
# Epoch 48/100
# 47428/47428 [==============================] - 18s 383us/step - loss: 0.0503 - accuracy: 0.9800 - val_loss: 0.6936 - val_accuracy: 0.8607
# Epoch 49/100
# 47428/47428 [==============================] - 18s 389us/step - loss: 0.0501 - accuracy: 0.9798 - val_loss: 0.7089 - val_accuracy: 0.8632
# Epoch 50/100
# 47428/47428 [==============================] - 19s 395us/step - loss: 0.0474 - accuracy: 0.9807 - val_loss: 0.7062 - val_accuracy: 0.8599

# %%
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 87.23%

# %%
from IPython.display import SVG
from keras.utils import model_to_dot
#model
SVG(model_to_dot(model,show_shapes=True,expand_nested=True,dpi=50).create(prog='dot', format='svg'))

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
def createConfusionMatrix(trueLabel,PredictedLabel):
    cm=confusion_matrix(trueLabel,PredictedLabel,normalize="true")
    return np.around(cm, decimals=2)

# %%
def plotConfusionMatrix(matrix):
  df_cm = pd.DataFrame(matrix,range(matrix.shape[0]),range(matrix.shape[1]))
  plt.figure(figsize = (50,50))
  sn.set(font_scale=1.5)
  sn.heatmap(df_cm, annot=True, annot_kws={"size": 15})

# %%
#Get the predicted classes for all the samples in testing set
y_pred = model.predict_classes(X_test)

# %%
#Create and plot the confusion matrix
cm = createConfusionMatrix(y_test.argmax(axis=1),y_pred)
plotConfusionMatrix(cm)

# %%
print(classification_report(y_test.argmax(axis=1),y_pred,zero_division=0)) #
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.70      0.69       235
#            1       0.87      0.86      0.87       230
#            2       0.96      0.96      0.96       228
#            3       0.95      0.96      0.95       224
#            4       0.97      0.96      0.96       224
#            5       0.97      0.96      0.97       227
#            6       0.94      0.96      0.95       227
#            7       0.97      0.95      0.96       224
#            8       0.96      0.94      0.95       220
#            9       0.91      0.92      0.91       221
#           10       0.92      0.94      0.93       326
#           11       0.95      0.89      0.92       237
#           12       0.78      0.82      0.80       257
#           13       0.91      0.92      0.92       252
#           14       0.93      0.92      0.93       303
#           15       0.93      0.92      0.92       230
#           16       0.89      0.88      0.89       243
#           17       0.94      0.94      0.94       253
#           18       0.78      0.82      0.80       275
#           19       0.89      0.92      0.90       230
#           20       0.92      0.97      0.95       233
#           21       0.94      0.93      0.94       257
#           22       0.90      0.96      0.93       244
#           23       0.94      0.95      0.94       287
#           24       0.62      0.64      0.63       291
#           25       0.91      0.87      0.89       246
#           26       0.93      0.89      0.91       221
#           27       0.93      0.93      0.93       292
#           28       0.74      0.77      0.76       283
#           29       0.89      0.91      0.90       277
#           30       0.89      0.90      0.89       233
#           31       0.81      0.75      0.78       231
#           32       0.83      0.78      0.80       228
#           33       0.83      0.72      0.77       230
#           34       0.91      0.91      0.91       228
#           35       0.79      0.84      0.82       225
#           36       0.85      0.84      0.84       246
#           37       0.91      0.91      0.91       222
#           38       0.80      0.74      0.77       227
#           39       0.92      0.92      0.92       223
#           40       0.93      0.93      0.93       260
#           41       0.94      0.90      0.92       221
#           42       0.88      0.87      0.88       221
#           43       0.95      0.94      0.94       225
#           44       0.93      0.90      0.92       240
#           45       0.92      0.89      0.91       221
#           46       0.94      0.88      0.91       221
#           47       0.74      0.83      0.78       226
#           48       0.90      0.93      0.92       223
#           49       0.90      0.90      0.90       241
#           50       0.64      0.68      0.66       244
#           51       0.89      0.89      0.89       221
#           52       0.85      0.90      0.87       225
#           53       0.90      0.88      0.89       239
#           54       0.72      0.71      0.72       239
#           55       0.89      0.92      0.90       236
#           56       0.86      0.86      0.86       222
#           57       0.75      0.77      0.76       221
#           58       0.77      0.81      0.79       221
#           59       0.76      0.78      0.77       221
#           60       0.92      0.88      0.90       223
#           61       0.85      0.73      0.79       221
#
#     accuracy                           0.87     14822
#    macro avg       0.87      0.87      0.87     14822
# weighted avg       0.87      0.87      0.87     14822
